# %% [markdown]
# ## Cricket Player Performance Prediction Using Machine Learning

# %% [markdown]
# ##### Importing libraries

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Importing Data

# %%
df = pd.read_csv('Batsman_Data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Bat1 Runs BF SR 4s 6s    Opposition   Ground   Start Date  \
# 0           1  DNB    -  -  -  -  -       v India   Nagpur  18 Dec 2009
# 1           2  DNB    -  -  -  -  -       v India  Kolkata  24 Dec 2009
# 2           3  DNB    -  -  -  -  -       v India    Delhi  27 Dec 2009
# 3           4  DNB    -  -  -  -  -  v Bangladesh    Dhaka   4 Jan 2010
# 4           5  DNB    -  -  -  -  -       v India    Dhaka   5 Jan 2010
#
#      Match_ID        Batsman  Player_ID
# 0  ODI # 2933  Oshane Thomas      49619
# 1  ODI # 2935  Oshane Thomas      49619
# 2  ODI # 2936  Oshane Thomas      49619
# 3  ODI # 2937  Oshane Thomas      49619
# 4  ODI # 2938  Oshane Thomas      49619

# %% [markdown]
# ##### shape

# %%
df.shape
# Out:
# (11149, 13)

# %% [markdown]
# ##### Null Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Bat1          0
# Runs          0
# BF            0
# SR            0
# 4s            0
# 6s            0
# Opposition    0
# Ground        0
# Start Date    0
# Match_ID      0
# Batsman       0
# Player_ID     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ##### Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11149 entries, 0 to 11148
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  11149 non-null  int64
#  1   Bat1        11149 non-null  object
#  2   Runs        11149 non-null  object
#  3   BF          11149 non-null  object
#  4   SR          11149 non-null  object
#  5   4s          11149 non-null  object
#  6   6s          11149 non-null  object
#  7   Opposition  11149 non-null  object
#  8   Ground      11149 non-null  object
#  9   Start Date  11149 non-null  object
#  10  Match_ID    11149 non-null  object
#  11  Batsman     11149 non-null  object
#  12  Player_ID   11149 non-null  int64
# dtypes: int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ##### Data cleaning and Feature Engineering

# %%
df.drop(['Unnamed: 0'], axis = 1 , inplace = True)

# %%
df.drop(df[df.Bat1 == 'DNB'].index, inplace=True)

# %%
df.drop(df[df.Bat1 == 'TDNB'].index, inplace=True)

# %%
df.drop(df[df.Bat1 == 'absent'].index, inplace=True)

# %%
df.drop(df[df.Bat1 == 'sub'].index, inplace=True)

# %%
df.head()
# Out:
#    Bat1 Runs BF     SR 4s 6s   Opposition       Ground   Start Date  \
# 5    0*    0  8   0.00  0  0      v India        Dhaka  10 Jan 2010
# 6    0*    0  0      -  0  0    v England     The Oval  28 Jun 2011
# 9    1*    1  3  33.33  0  0    v England   Nottingham   6 Jul 2011
# 10   0*    0  2   0.00  0  0  v Australia    Pallekele  10 Aug 2011
# 11    0    0  2   0.00  0  0   v Pakistan  Dubai (DSC)  11 Nov 2011
#
#       Match_ID        Batsman  Player_ID
# 5   ODI # 2941  Oshane Thomas      49619
# 6   ODI # 3165  Oshane Thomas      49619
# 9   ODI # 3169  Oshane Thomas      49619
# 10  ODI # 3175  Oshane Thomas      49619
# 11  ODI # 3212  Oshane Thomas      49619

# %%
df['Bat1'] = df['Bat1'].str.replace('*', '.')
df['SR'] = df['SR'].str.replace('-', '0')
df['Runs'] = df['Runs'].str.replace('-', '0')
df['4s'] = df['4s'].str.replace('-', '0')
df['6s'] = df['6s'].str.replace('-', '0')
df.head()
# Out:
# C:\Users\bhush\AppData\Local\Temp\ipykernel_6732\4134432060.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Bat1'] = df['Bat1'].str.replace('*', '.')
#    Bat1 Runs BF     SR 4s 6s   Opposition       Ground   Start Date  \
# 5    0.    0  8   0.00  0  0      v India        Dhaka  10 Jan 2010
# 6    0.    0  0      0  0  0    v England     The Oval  28 Jun 2011
# 9    1.    1  3  33.33  0  0    v England   Nottingham   6 Jul 2011
# 10   0.    0  2   0.00  0  0  v Australia    Pallekele  10 Aug 2011
# 11    0    0  2   0.00  0  0   v Pakistan  Dubai (DSC)  11 Nov 2011
#
#       Match_ID        Batsman  Player_ID
# 5   ODI # 2941  Oshane Thomas      49619
# 6   ODI # 3165  Oshane Thomas      49619
# 9   ODI # 3169  Oshane Thomas      49619
# 10  ODI # 3175  Oshane Thomas      49619
# 11  ODI # 3212  Oshane Thomas      49619

# %%
df['SR']=df['SR'].astype(float)
df['Runs']=df['Runs'].astype(float)
df['4s']=df['4s'].astype(float)
df['6s']=df['6s'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8918 entries, 5 to 11146
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Bat1        8918 non-null   object
#  1   Runs        8918 non-null   float64
#  2   BF          8918 non-null   object
#  3   SR          8918 non-null   float64
#  4   4s          8918 non-null   float64
#  5   6s          8918 non-null   float64
#  6   Opposition  8918 non-null   object
#  7   Ground      8918 non-null   object
#  8   Start Date  8918 non-null   object
#  9   Match_ID    8918 non-null   object
#  10  Batsman     8918 non-null   object
#  11  Player_ID   8918 non-null   int64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 905.7+ KB

# %% [markdown]
# ##### summary

# %%
df.describe()
# Out:
#               Runs           SR           4s           6s     Player_ID
# count  8918.000000  8918.000000  8918.000000  8918.000000  8.918000e+03
# mean     28.709352    77.978627     2.601144     0.539807  2.110862e+05
# std      31.826135    50.343366     3.232154     1.180729  1.848679e+05
# min       0.000000     0.000000     0.000000     0.000000  5.334000e+03
# 25%       5.000000    50.000000     0.000000     0.000000  4.482800e+04
# 50%      17.000000    75.945000     1.000000     0.000000  2.277600e+05
# 75%      42.000000   100.000000     4.000000     1.000000  3.183390e+05
# max     264.000000   600.000000    33.000000    16.000000  1.158100e+06

# %%
Total_runs_by_batsman = df.groupby(df['Batsman'])['Runs'].sum().sort_values(ascending = False)
Total_runs_by_batsman
# Out:
# Batsman
# Virat Kohli          10843.0
# MS Dhoni             10500.0
# Chris Gayle          10151.0
# Ross Taylor           8026.0
# Rohit Sharma          8010.0
#                       ...
# Anrich Nortje            8.0
# Jason Behrendorff        7.0
# Tabraiz Shamsi           0.0
# Mohammad Hasnain         0.0
# Nicholas Pooran          0.0
# Name: Runs, Length: 148, dtype: float64

# %%
df.groupby(by = ['Batsman','Ground'])['Runs'].sum().sort_values(ascending = False)
# Out:
# Batsman           Ground
# Tamim Iqbal       Dhaka           2619.0
# Shakib Al Hasan   Dhaka           2472.0
# Mushfiqur Rahim   Dhaka           2351.0
# Mahmudullah       Dhaka           1616.0
# Shoaib Malik      Lahore          1030.0
#                                    ...
# Kemar Roach       Chattogram         0.0
#                   Chennai            0.0
#                   Harare             0.0
# Andre Russell     Johannesburg       0.0
# Yuzvendra Chahal  Wellington         0.0
# Name: Runs, Length: 3668, dtype: float64

# %%
df.groupby(by = ['Batsman','Opposition'])['Runs'].sum().sort_values(ascending = False)
# Out:
# Batsman         Opposition
# MS Dhoni        v Sri Lanka      2383.0
# Virat Kohli     v Sri Lanka      2186.0
# Rohit Sharma    v Australia      1980.0
# Virat Kohli     v West Indies    1840.0
# Eoin Morgan     v Australia      1815.0
#                                   ...
# Shaheen Afridi  v New Zealand       0.0
# Hamid Hassan    v Sri Lanka         0.0
#                 v Netherlands       0.0
#                 v England           0.0
# Kusal Mendis    v Afghanistan       0.0
# Name: Runs, Length: 1328, dtype: float64

# %%
df.columns
# Out:
# Index(['Bat1', 'Runs', 'BF', 'SR', '4s', '6s', 'Opposition', 'Ground',
#        'Start Date', 'Match_ID', 'Batsman', 'Player_ID'],
#       dtype='object')

# %%
for col in df.columns:
    print(col + '\n===========')
    print(df[col].value_counts())
    print('\n============================================')
# Out:
# Bat1
# ===========
# 0       655
# 1       338
# 2       260
# 4       229
# 5       200
#        ...
# 180.      1
# 145.      1
# 183.      1
# 109.      1
# 164       1
# Name: Bat1, Length: 319, dtype: int64
#
# ============================================
# Runs
# ===========
# 0.0      800
# 1.0      438
# 2.0      325
# 4.0      278
# 5.0      244
#         ...
# 168.0      1
# 159.0      1
# 215.0      1
# 176.0      1
# 164.0      1
# Name: Runs, Length: 179, dtype: int64
#
# ============================================
# BF
# ===========
# 1      336
# 3      277
# 5      271
# 2      263
# 4      259
#       ...
# 158      1
# 173      1
# 148      1
# 159      1
# 155      1
# Name: BF, Length: 162, dtype: int64
#
# ============================================
# SR
# ===========
# 0.00      800
# 100.00    403
# 50.00     286
# 66.66     181
# 33.33     167
#          ...
# 105.97      1
# 75.51       1
# 137.93      1
# 42.00       1
# 49.45       1
# Name: SR, Length: 2031, dtype: int64
#
# ============================================
# 4s
# ===========
# 0.0     2901
# 1.0     1630
# 2.0     1084
# 3.0      835
# 4.0      594
# 5.0      496
# 6.0      342
# 7.0      279
# 8.0      216
# 9.0      148
# 10.0      91
# 11.0      89
# 12.0      64
# 13.0      43
# 16.0      26
# 15.0      24
# 14.0      19
# 17.0      13
# 18.0       7
# 19.0       5
# 22.0       3
# 24.0       3
# 20.0       3
# 21.0       2
# 33.0       1
# Name: 4s, dtype: int64
#
# ============================================
# 6s
# ===========
# 0.0     6368
# 1.0     1481
# 2.0      531
# 3.0      255
# 4.0      124
# 5.0       77
# 6.0       40
# 7.0       14
# 8.0        9
# 9.0        5
# 11.0       5
# 12.0       3
# 16.0       2
# 10.0       2
# 14.0       1
# 13.0       1
# Name: 6s, dtype: int64
#
# ============================================
# Opposition
# ===========
# v India           1004
# v Australia        991
# v Sri Lanka        982
# v England          882
# v Pakistan         837
# v New Zealand      819
# v South Africa     748
# v West Indies      679
# v Zimbabwe         668
# v Bangladesh       490
# v Ireland          339
# v Scotland         129
# v Afghanistan      115
# v U.A.E.            50
# v Kenya             50
# v Netherlands       48
# v Canada            41
# v Hong Kong         28
# v Bermuda            6
# v Africa XI          5
# v P.N.G.             4
# v Asia XI            3
# Name: Opposition, dtype: int64
#
# ============================================
# Ground
# ===========
# Dhaka            711
# Harare           296
# Abu Dhabi        281
# Sharjah          271
# Colombo (RPS)    261
#                 ...
# Cairns             1
# Georgetown         1
# Nairobi            1
# Canterbury         1
# Vijayawada         1
# Name: Ground, Length: 133, dtype: int64
#
# ============================================
# Start Date
# ===========
# 19 Jan 2018    42
# 2 Mar 2019     34
# 9 Nov 2018     34
# 10 Mar 2019    34
# 20 Feb 2019    32
#                ..
# 16 Mar 2004     1
# 13 Mar 2004     1
# 17 Jan 2004     1
# 10 May 2006     1
# 13 Jun 2006     1
# Name: Start Date, Length: 1570, dtype: int64
#
# ============================================
# Match_ID
# ===========
# ODI # 4066    21
# ODI # 4106    20
# ODI # 3982    20
# ODI # 3980    19
# ODI # 4092    19
#               ..
# ODI # 2294     1
# ODI # 2291     1
# ODI # 2290     1
# ODI # 2286     1
# ODI # 3977     1
# Name: Match_ID, Length: 1780, dtype: int64
#
# ============================================
# Batsman
# ===========
# MS Dhoni             289
# Chris Gayle          283
# Shoaib Malik         254
# Virat Kohli          219
# Mohammad Hafeez      207
#                     ...
# Jason Behrendorff      2
# Abid Ali               2
# Anrich Nortje          1
# Nicholas Pooran        1
# Mohammad Hasnain       1
# Name: Batsman, Length: 148, dtype: int64
#
# ============================================
# Player_ID
# ===========
# 28081      289
# 51880      283
# 42657      254
# 253802     219
# 41434      207
#           ...
# 272477       2
# 39950        2
# 481979       1
# 1158100      1
# 604302       1
# Name: Player_ID, Length: 149, dtype: int64
#
# ============================================

# %%
df.head()
# Out:
#    Bat1  Runs BF     SR   4s   6s   Opposition       Ground   Start Date  \
# 5    0.   0.0  8   0.00  0.0  0.0      v India        Dhaka  10 Jan 2010
# 6    0.   0.0  0   0.00  0.0  0.0    v England     The Oval  28 Jun 2011
# 9    1.   1.0  3  33.33  0.0  0.0    v England   Nottingham   6 Jul 2011
# 10   0.   0.0  2   0.00  0.0  0.0  v Australia    Pallekele  10 Aug 2011
# 11    0   0.0  2   0.00  0.0  0.0   v Pakistan  Dubai (DSC)  11 Nov 2011
#
#       Match_ID        Batsman  Player_ID
# 5   ODI # 2941  Oshane Thomas      49619
# 6   ODI # 3165  Oshane Thomas      49619
# 9   ODI # 3169  Oshane Thomas      49619
# 10  ODI # 3175  Oshane Thomas      49619
# 11  ODI # 3212  Oshane Thomas      49619

# %%
bd_induvidual = df.query('Batsman == "Virat Kohli "')
bd_induvidual
# Out:
#      Bat1   Runs   BF      SR    4s   6s   Opposition              Ground  \
# 6676   12   12.0   22   54.54   1.0  0.0  v Sri Lanka            Dambulla
# 6677   37   37.0   67   55.22   6.0  0.0  v Sri Lanka            Dambulla
# 6678   25   25.0   38   65.78   4.0  0.0  v Sri Lanka       Colombo (RPS)
# 6679   54   54.0   66   81.81   7.0  0.0  v Sri Lanka       Colombo (RPS)
# 6680   31   31.0   46   67.39   3.0  1.0  v Sri Lanka       Colombo (RPS)
# ...   ...    ...  ...     ...   ...  ...          ...                 ...
# 6898   44   44.0   45   97.77   6.0  1.0  v Australia  Hyderabad (Deccan)
# 6899  116  116.0  120   96.66  10.0  0.0  v Australia              Nagpur
# 6900  123  123.0   95  129.47  16.0  1.0  v Australia              Ranchi
# 6901    7    7.0    6  116.66   1.0  0.0  v Australia              Mohali
# 6902   20   20.0   22   90.90   2.0  0.0  v Australia               Delhi
#
#        Start Date    Match_ID       Batsman  Player_ID
# 6676  18 Aug 2008  ODI # 2742  Virat Kohli      253802
# 6677  20 Aug 2008  ODI # 2745  Virat Kohli      253802
# 6678  24 Aug 2008  ODI # 2750  Virat Kohli      253802
# 6679  27 Aug 2008  ODI # 2755  Virat Kohli      253802
# 6680  29 Aug 2008  ODI # 2756  Virat Kohli      253802
# ...           ...         ...           ...        ...
# 6898   2 Mar 2019  ODI # 4102  Virat Kohli      253802
# 6899   5 Mar 2019  ODI # 4106  Virat Kohli      253802
# 6900   8 Mar 2019  ODI # 4109  Virat Kohli      253802
# 6901  10 Mar 2019  ODI # 4111  Virat Kohli      253802
# 6902  13 Mar 2019  ODI # 4113  Virat Kohli      253802
#
# [219 rows x 12 columns]

# %%
df.drop(columns = ['Match_ID', 'Player_ID', 'Start Date'], axis = 1, inplace =True)

# %%
df.head()
# Out:
#    Bat1  Runs BF     SR   4s   6s   Opposition       Ground        Batsman
# 5    0.   0.0  8   0.00  0.0  0.0      v India        Dhaka  Oshane Thomas
# 6    0.   0.0  0   0.00  0.0  0.0    v England     The Oval  Oshane Thomas
# 9    1.   1.0  3  33.33  0.0  0.0    v England   Nottingham  Oshane Thomas
# 10   0.   0.0  2   0.00  0.0  0.0  v Australia    Pallekele  Oshane Thomas
# 11    0   0.0  2   0.00  0.0  0.0   v Pakistan  Dubai (DSC)  Oshane Thomas

# %%
df = pd.get_dummies(data = df, columns = ['Opposition', 'Ground', 'Batsman'], drop_first = True)

# %%
df.head()
# Out:
#    Bat1  Runs BF     SR   4s   6s  Opposition_v Africa XI  \
# 5    0.   0.0  8   0.00  0.0  0.0                       0
# 6    0.   0.0  0   0.00  0.0  0.0                       0
# 9    1.   1.0  3  33.33  0.0  0.0                       0
# 10   0.   0.0  2   0.00  0.0  0.0                       0
# 11    0   0.0  2   0.00  0.0  0.0                       0
#
#     Opposition_v Asia XI  Opposition_v Australia  Opposition_v Bangladesh  \
# 5                      0                       0                        0
# 6                      0                       0                        0
# 9                      0                       0                        0
# 10                     0                       1                        0
# 11                     0                       0                        0
#
#     ...  Batsman_Tamim Iqbal  Batsman_Thisara Perera  Batsman_Tim Southee  \
# 5   ...                    0                       0                    0
# 6   ...                    0                       0                    0
# 9   ...                    0                       0                    0
# 10  ...                    0                       0                    0
# 11  ...                    0                       0                    0
#
#     Batsman_Tom Curran  Batsman_Tom Latham   Batsman_Trent Boult  \
# 5                    0                    0                    0
# 6                    0                    0                    0
# 9                    0                    0                    0
# 10                   0                    0                    0
# 11                   0                    0                    0
#
#     Batsman_Usman Khawaja  Batsman_Vijay Shankar  Batsman_Virat Kohli   \
# 5                       0                      0                     0
# 6                       0                      0                     0
# 9                       0                      0                     0
# 10                      0                      0                     0
# 11                      0                      0                     0
#
#     Batsman_Yuzvendra Chahal
# 5                          0
# 6                          0
# 9                          0
# 10                         0
# 11                         0
#
# [5 rows x 306 columns]

# %%
df.shape
# Out:
# (8918, 306)

# %%
df.columns
# Out:
# Index(['Bat1', 'Runs', 'BF', 'SR', '4s', '6s', 'Opposition_v Africa XI',
#        'Opposition_v Asia XI', 'Opposition_v Australia',
#        'Opposition_v Bangladesh',
#        ...
#        'Batsman_Tamim Iqbal', 'Batsman_Thisara Perera', 'Batsman_Tim Southee',
#        'Batsman_Tom Curran', 'Batsman_Tom Latham ', 'Batsman_Trent Boult',
#        'Batsman_Usman Khawaja', 'Batsman_Vijay Shankar',
#        'Batsman_Virat Kohli ', 'Batsman_Yuzvendra Chahal'],
#       dtype='object', length=306)

# %%
df.head()
# Out:
#    Bat1  Runs BF     SR   4s   6s  Opposition_v Africa XI  \
# 5    0.   0.0  8   0.00  0.0  0.0                       0
# 6    0.   0.0  0   0.00  0.0  0.0                       0
# 9    1.   1.0  3  33.33  0.0  0.0                       0
# 10   0.   0.0  2   0.00  0.0  0.0                       0
# 11    0   0.0  2   0.00  0.0  0.0                       0
#
#     Opposition_v Asia XI  Opposition_v Australia  Opposition_v Bangladesh  \
# 5                      0                       0                        0
# 6                      0                       0                        0
# 9                      0                       0                        0
# 10                     0                       1                        0
# 11                     0                       0                        0
#
#     ...  Batsman_Tamim Iqbal  Batsman_Thisara Perera  Batsman_Tim Southee  \
# 5   ...                    0                       0                    0
# 6   ...                    0                       0                    0
# 9   ...                    0                       0                    0
# 10  ...                    0                       0                    0
# 11  ...                    0                       0                    0
#
#     Batsman_Tom Curran  Batsman_Tom Latham   Batsman_Trent Boult  \
# 5                    0                    0                    0
# 6                    0                    0                    0
# 9                    0                    0                    0
# 10                   0                    0                    0
# 11                   0                    0                    0
#
#     Batsman_Usman Khawaja  Batsman_Vijay Shankar  Batsman_Virat Kohli   \
# 5                       0                      0                     0
# 6                       0                      0                     0
# 9                       0                      0                     0
# 10                      0                      0                     0
# 11                      0                      0                     0
#
#     Batsman_Yuzvendra Chahal
# 5                          0
# 6                          0
# 9                          0
# 10                         0
# 11                         0
#
# [5 rows x 306 columns]

# %%
y = df['Runs']

# %%
x = df.drop(['Runs'], axis=1)

# %%
y
# Out:
# 5         0.0
# 6         0.0
# 9         1.0
# 10        0.0
# 11        0.0
#          ...
# 11142     0.0
# 11143    15.0
# 11144    46.0
# 11145     3.0
# 11146     1.0
# Name: Runs, Length: 8918, dtype: float64

# %%
x
# Out:
#       Bat1  BF     SR   4s   6s  Opposition_v Africa XI  Opposition_v Asia XI  \
# 5       0.   8   0.00  0.0  0.0                       0                     0
# 6       0.   0   0.00  0.0  0.0                       0                     0
# 9       1.   3  33.33  0.0  0.0                       0                     0
# 10      0.   2   0.00  0.0  0.0                       0                     0
# 11       0   2   0.00  0.0  0.0                       0                     0
# ...    ...  ..    ...  ...  ...                     ...                   ...
# 11142   0.   2   0.00  0.0  0.0                       0                     0
# 11143   15  46  32.60  1.0  0.0                       0                     0
# 11144   46  61  75.40  6.0  1.0                       0                     0
# 11145    3   6  50.00  0.0  0.0                       0                     0
# 11146    1   8  12.50  0.0  0.0                       0                     0
#
#        Opposition_v Australia  Opposition_v Bangladesh  Opposition_v Bermuda  \
# 5                           0                        0                     0
# 6                           0                        0                     0
# 9                           0                        0                     0
# 10                          1                        0                     0
# 11                          0                        0                     0
# ...                       ...                      ...                   ...
# 11142                       0                        1                     0
# 11143                       0                        0                     0
# 11144                       0                        0                     0
# 11145                       0                        0                     0
# 11146                       0                        0                     0
#
#        ...  Batsman_Tamim Iqbal  Batsman_Thisara Perera  Batsman_Tim Southee  \
# 5      ...                    0                       0                    0
# 6      ...                    0                       0                    0
# 9      ...                    0                       0                    0
# 10     ...                    0                       0                    0
# 11     ...                    0                       0                    0
# ...    ...                  ...                     ...                  ...
# 11142  ...                    0                       0                    0
# 11143  ...                    0                       0                    0
# 11144  ...                    0                       0                    0
# 11145  ...                    0                       0                    0
# 11146  ...                    0                       0                    0
#
#        Batsman_Tom Curran  Batsman_Tom Latham   Batsman_Trent Boult  \
# 5                       0                    0                    0
# 6                       0                    0                    0
# 9                       0                    0                    0
# 10                      0                    0                    0
# 11                      0                    0                    0
# ...                   ...                  ...                  ...
# 11142                   0                    0                    0
# 11143                   0                    0                    0
# 11144                   0                    0                    0
# 11145                   0                    0                    0
# 11146                   0                    0                    0
#
#        Batsman_Usman Khawaja  Batsman_Vijay Shankar  Batsman_Virat Kohli   \
# 5                          0                      0                     0
# 6                          0                      0                     0
# 9                          0                      0                     0
# 10                         0                      0                     0
# 11                         0                      0                     0
# ...                      ...                    ...                   ...
# 11142                      0                      0                     0
# 11143                      0                      0                     0
# 11144                      0                      0                     0
# 11145                      0                      0                     0
# 11146                      0                      0                     0
#
#        Batsman_Yuzvendra Chahal
# 5                             0
# 6                             0
# 9                             0
# 10                            0
# 11                            0
# ...                         ...
# 11142                         0
# 11143                         0
# 11144                         0
# 11145                         0
# 11146                         0
#
# [8918 rows x 305 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state=42)

# %%
print('x_train shape :', x_train.shape)
print('x_test shape :', x_test.shape)
print('y_train shape :', y_train.shape)
print('y_test shape :', y_test.shape)
# Out:
# x_train shape : (7134, 305)
# x_test shape : (1784, 305)
# y_train shape : (7134,)
# y_test shape : (1784,)

# %%
#from sklearn.preprocessing import StandardScaler

sd = StandardScaler()
x_train = sd.fit_transform(x_train)
x_test = sd.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
models={
    'LR':LinearRegression(),
    'KNNR':KNeighborsRegressor(),
    'SVR':SVR(),
    'DT':DecisionTreeRegressor(),
    'RF':RandomForestRegressor() 
}

# %%
for name, model in models.items():
    print(f'Using model: {name}')
    model.fit(x_train, y_train)
    print(f'Training score :{model.score(x_train,y_train)}')
    print(f'Test Score :{model.score(x_test,y_test)}')
    y_pred= model.predict(x_test)
    print(f'RMSE: {np.sqrt(mean_squared_error(y_test,y_pred))}')
    print('======================================================')
# Out:
# Using model: LR
# Training score :1.0
# Test Score :0.9999999796392584
# RMSE: 0.004688894843710456
# ======================================================
# Using model: KNNR
# Training score :0.5898188800288545
# Test Score :0.3761508850328289
# RMSE: 25.95454849239235
# ======================================================
# Using model: SVR
# Training score :0.7578189922120923
# Test Score :0.7427943702862388
# RMSE: 16.66533053325233
# ======================================================
# Using model: DT
# Training score :1.0
# Test Score :0.999125822057778
# RMSE: 0.9715689313377652
# ======================================================
# Using model: RF
# Training score :0.999907170511065
# Test Score :0.9999098105841215
# RMSE: 0.3120696139424478
# ======================================================

# %%
model = LinearRegression()
model = model.fit(x_train,y_train)

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([-3.55271368e-15,  1.40000000e+01,  1.01000000e+02, ...,
#         7.00000000e+00,  2.90000000e+01,  1.60000000e+01])

# %%
y_test.values
# Out:
# array([  0.,  14., 101., ...,   7.,  29.,  16.])
